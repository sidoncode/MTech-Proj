# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# Load the data
df = pd.read_csv('/content/ADANIENT.NS.csv')

# %%
# Visualize the data
plt.figure(figsize=(16,8))
plt.title('Adani Stock Price')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.show()

# %%
# Split the data into training and testing sets
train_size = int(len(df) * 0.8)
train_data = df.iloc[:train_size]['Close'].values.reshape(-1, 1)
test_data = df.iloc[train_size:]['Close'].values.reshape(-1, 1)

# %%
# Normalize the data
scaler = MinMaxScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)
train_data_gen = TimeseriesGenerator(train_data, train_data, length=10, batch_size=1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(10, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(train_data_gen, epochs=100)
# Out:
# Epoch 1/100
# 189/189 [==============================] - 12s 19ms/step - loss: 0.0231
# Epoch 2/100
# 189/189 [==============================] - 5s 29ms/step - loss: 0.0186
# Epoch 3/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0117
# Epoch 4/100
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0111
# Epoch 5/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0112
# Epoch 6/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0121
# Epoch 7/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0116
# Epoch 8/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0109
# Epoch 9/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0087
# Epoch 10/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0099
# Epoch 11/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0089
# Epoch 12/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0096
# Epoch 13/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0088
# Epoch 14/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0112
# Epoch 15/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0076
# Epoch 16/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0070
# Epoch 17/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0068
# Epoch 18/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0096
# Epoch 19/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0078
# Epoch 20/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0060
# Epoch 21/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0069
# Epoch 22/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0080
# Epoch 23/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0063
# Epoch 24/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0063
# Epoch 25/100
# 189/189 [==============================] - 4s 18ms/step - loss: 0.0068
# Epoch 26/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0049
# Epoch 27/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0052
# Epoch 28/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0058
# Epoch 29/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0064
# Epoch 30/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0036
# Epoch 31/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0043
# Epoch 32/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0053
# Epoch 33/100
# 189/189 [==============================] - 5s 25ms/step - loss: 0.0041
# Epoch 34/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0047
# Epoch 35/100
# 189/189 [==============================] - 3s 18ms/step - loss: 0.0040
# Epoch 36/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0047
# Epoch 37/100
# 189/189 [==============================] - 3s 18ms/step - loss: 0.0061
# Epoch 38/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0043
# Epoch 39/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0045
# Epoch 40/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0036
# Epoch 41/100
# 189/189 [==============================] - 4s 18ms/step - loss: 0.0047
# Epoch 42/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0046
# Epoch 43/100
# 189/189 [==============================] - 3s 18ms/step - loss: 0.0036
# Epoch 44/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0053
# Epoch 45/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0040
# Epoch 46/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0031
# Epoch 47/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0041
# Epoch 48/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0034
# Epoch 49/100
# 189/189 [==============================] - 3s 18ms/step - loss: 0.0034
# Epoch 50/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0039
# Epoch 51/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0037
# Epoch 52/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0037
# Epoch 53/100
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0045
# Epoch 54/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0038
# Epoch 55/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0028
# Epoch 56/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0042
# Epoch 57/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0031
# Epoch 58/100
# 189/189 [==============================] - 5s 25ms/step - loss: 0.0036
# Epoch 59/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0026
# Epoch 60/100
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0033
# Epoch 61/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0040
# Epoch 62/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0035
# Epoch 63/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0029
# Epoch 64/100
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0031
# Epoch 65/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0026
# Epoch 66/100
# 189/189 [==============================] - 5s 24ms/step - loss: 0.0032
# Epoch 67/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0029
# Epoch 68/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0030
# Epoch 69/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0031
# Epoch 70/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0026
# Epoch 71/100
# 189/189 [==============================] - 5s 24ms/step - loss: 0.0030
# Epoch 72/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0033
# Epoch 73/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0034
# Epoch 74/100
# 189/189 [==============================] - 5s 24ms/step - loss: 0.0042
# Epoch 75/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0028
# Epoch 76/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0026
# Epoch 77/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0025
# Epoch 78/100
# 189/189 [==============================] - 4s 20ms/step - loss: 0.0034
# Epoch 79/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0028
# Epoch 80/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0030
# Epoch 81/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0030
# Epoch 82/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0034
# Epoch 83/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0031
# Epoch 84/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0031
# Epoch 85/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0027
# Epoch 86/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0028
# Epoch 87/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0028
# Epoch 88/100
# 189/189 [==============================] - 4s 22ms/step - loss: 0.0025
# Epoch 89/100
# 189/189 [==============================] - 6s 31ms/step - loss: 0.0025
# Epoch 90/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0029
# Epoch 91/100
# 189/189 [==============================] - 5s 24ms/step - loss: 0.0025
# Epoch 92/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0024
# Epoch 93/100
# 189/189 [==============================] - 4s 21ms/step - loss: 0.0027
# Epoch 94/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0027
# Epoch 95/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0029
# Epoch 96/100
# 189/189 [==============================] - 4s 24ms/step - loss: 0.0034
# Epoch 97/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0026
# Epoch 98/100
# 189/189 [==============================] - 4s 23ms/step - loss: 0.0028
# Epoch 99/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0027
# Epoch 100/100
# 189/189 [==============================] - 4s 19ms/step - loss: 0.0023

# %%
# Predict the stock price
test_data_gen = TimeseriesGenerator(test_data, test_data, length=10, batch_size=1)
predictions = model.predict(test_data_gen)

# Inverse transform the data
predictions = scaler.inverse_transform(predictions)
# Out:
# 40/40 [==============================] - 2s 5ms/step

# %%
# Plot the predicted stock price
plt.figure(figsize=(16,8))
plt.title('Adani Stock Price Prediction')
plt.plot(df.iloc[train_size+10:]['Close'], label='Actual Price')
plt.plot(predictions, label='Predicted Price')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.legend(fontsize=18)
plt.show()
